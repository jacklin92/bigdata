# %% [markdown]
# # Calculate 200 frequent keywords for each category
#
# Count keywords from word-pos pair for each category and save them

# %%
import pandas as pd

# %%
df = pd.read_csv('cna_news_preprocessed.csv',sep='|')

# %%
df.head(1)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
#
#                                              content sentiment summary  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('台灣', 20), ('教友', 7), ('札尼', 4), ('布雷西亞', 4)...
#
#                                               tokens  \
# 0  ['梵蒂岡', '宗座', '圖書館', '總', '館長', '札尼', '今天', '率...
#
#                                            tokens_v2  \
# 0  ['梵蒂岡', '宗座', '圖書館', '館長', '札尼', '北義', '社會', '...
#
#                                             entities  \
# 0  [NerToken(word='梵蒂岡', ner='GPE', idx=(0, 3)), ...
#
#                                            token_pos  \
# 0  [('梵蒂岡', 'Nc'), ('宗座', 'Na'), ('圖書館', 'Nc'), (...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...

# %%
df.shape
# Out:
# (12, 14)

# %%
df.groupby('category').count()
# Out:
#           item_id  date  title  content  sentiment  summary  top_key_freq  \
# category
# 政治              4     4      4        4          4        4             4
# 科技              4     4      4        4          4        4             4
# 運動              4     4      4        4          4        4             4
#
#           tokens  tokens_v2  entities  token_pos  link  photo_link
# category
# 政治             4          4         4          4     4           3
# 科技             4          4         4          4     4           1
# 運動             4          4         4          4     4           4

# %%
df.head(1)
# Out:
#            item_id        date category                    title  \
# 0  aipl_20250304_1  2025-03-04       政治  梵蒂岡圖書館長率團參觀台灣使館  力薦值得訪台
#
#                                              content sentiment summary  \
# 0  梵蒂岡宗座圖書館總館長札尼今天率領數十位北義的社會菁英教友拜會駐教廷大使館。曾訪台的札尼致詞...        暫無      暫無
#
#                                         top_key_freq  \
# 0  [('台灣', 20), ('教友', 7), ('札尼', 4), ('布雷西亞', 4)...
#
#                                               tokens  \
# 0  ['梵蒂岡', '宗座', '圖書館', '總', '館長', '札尼', '今天', '率...
#
#                                            tokens_v2  \
# 0  ['梵蒂岡', '宗座', '圖書館', '館長', '札尼', '北義', '社會', '...
#
#                                             entities  \
# 0  [NerToken(word='梵蒂岡', ner='GPE', idx=(0, 3)), ...
#
#                                            token_pos  \
# 0  [('梵蒂岡', 'Nc'), ('宗座', 'Na'), ('圖書館', 'Nc'), (...
#
#                            link  \
# 0  /news/aipl/202503040022.aspx
#
#                                           photo_link
# 0  https://imgcdn.cna.com.tw/www/WebPhotos/200/20...

# %% [markdown]
# ## Filter category

# %%
# df_group = df[df.category == '政治']
df_group = df.query('category == "政治"')

# %%
df_group['token_pos']
# Out:
# 0    [('梵蒂岡', 'Nc'), ('宗座', 'Na'), ('圖書館', 'Nc'), (...
# 1    [('由', 'P'), ('外交部', 'Nc'), ('中美洲', 'Nc'), ('經...
# 2    [('經民連', 'P'), ('與', 'Caa'), ('台灣', 'Nc'), ('東...
# 3    [('台灣', 'Nc'), ('去年度', 'Nd'), ('稅收', 'Na'), ('...
# Name: token_pos, dtype: object

# %%
len(df_group['token_pos'])
# Out:
# 4

# %% [markdown]
# # Count top 200 word frequency for each category
#
# ## You can try it out step by step by yourself!

# %%
from collections import Counter

# %%
news_links =['aipl', 'ait', 'aspt']
news_categories=['政治','科技','運動']
# news_links =['aipl', 'ait', 'aspt', 'asc', 'aie', 'amov','ahel','aopl','asoc','acul','acn']
# news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']

# %%
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# %%
top_cate_words={} # final result
counter_all = Counter() # counter for category '全部'
for category in news_categories:
    
    # df yesterday-->This is your homework
    # df=df[(df.date >= start_date) & (df.date <= end_date)]
    
    # df category
    df_group = df[df.category == category]
    
    # concatenate all filtered words in the same category
    words_group = []
    for row in df_group.token_pos:
        
        # filter words for each news
        filtered_words =[]
        for (word, pos) in eval(row):
            if (len(word) >= 2) & (pos in allowedPOS):
                filtered_words.append(word)
                
        # concatenate filtered words  
        words_group += filtered_words

    # now we can count word frequency
    counter = Counter( words_group )
    
    # concatenate all counters 
    counter_all += counter
    topwords = counter.most_common(20)

    # store topwords
    top_cate_words[category]= topwords

# Process category '全部'
top_cate_words['全部'] = counter_all.most_common(20)

# %%
words_group
# Out:
# ['中職',
#  '統一7-ELEVEn',
#  '獅隊',
#  '野手',
#  '陳傑憲',
#  '公司',
#  '律師',
#  '聲明',
#  '負責人',
#  '股東',
#  '帳務',
#  '糾紛',
#  '陳傑憲',
#  '聲明',
#  '運動',
#  '行銷',
#  '律師',
#  '聲明',
#  '公司',
#  '詹姓',
#  '負責人',
#  '丈夫',
#  '蔡姓',
#  '股東',
#  '公司',
#  '時期',
#  '金流',
#  '詹姓',
#  '負責人',
#  '期間',
#  '帳目',
#  '球員',
#  '費用',
#  '合約',
#  '內容',
#  '詹姓',
#  '負責人',
#  '期間',
#  '義務',
#  '公司',
#  '資產',
#  '律師',
#  '程序',
#  '中華職',
#  '棒球員工會',
#  '工會',
#  '會員',
#  '權益',
#  '狀況',
#  '球團',
#  '單位',
#  '市場',
#  '環境',
#  '整體',
#  '市場',
#  '需求',
#  '前提下',
#  '規範',
#  '陳傑憲新',
#  '合約',
#  '獅隊',
#  '合約',
#  '新台幣',
#  '合約',
#  '陳傑憲',
#  '陳傑憲',
#  '公司',
#  '獅隊',
#  '領隊',
#  '蘇泰安',
#  '陳傑憲',
#  '蔡姓',
#  '經紀人',
#  '合約',
#  '陳傑憲也',
#  '聲明',
#  '經紀',
#  '經紀人Lio',
#  '團隊',
#  '合約',
#  '進展',
#  '台灣',
#  '超馬',
#  '運動員',
#  '陳彥博',
#  '北極圈',
#  '長征賽',
#  '賽程',
#  '雙腳',
#  '水泡',
#  '狀況',
#  '加拿大',
#  '北極圈',
#  '長征賽',
#  '環境',
#  '攝氏',
#  '冰雪',
#  '荒野',
#  '亞洲',
#  '選手',
#  '亞洲',
#  '選手',
#  '陳彥博',
#  '加拿大',
#  '台北',
#  '高雄',
#  '雪橇',
#  '訓練',
#  '陽明山',
#  '訓練',
#  '挑戰',
#  '決心',
#  '毅力',
#  '行動',
#  '心全意',
#  '夢想',
#  '陳彥',
#  '群位置',
#  '檢查站',
#  '賽程',
#  '排名',
#  '英國',
#  '選手',
#  '貝爾奇爾',
#  '澳洲',
#  '選手',
#  '庫克斯',
#  '低溫',
#  '距離',
#  '陳彥博',
#  '雙腳',
#  '水泡',
#  '灼熱感',
#  '人員',
#  '檢查站',
#  '小時',
#  '傷口',
#  '沿途',
#  '襪子',
#  '中職',
#  '兄弟',
#  '總冠軍',
#  '球團',
#  '球員',
#  '結果',
#  '整體',
#  '薪資',
#  '調幅',
#  '許基宏',
#  '月薪',
#  '新台幣',
#  '合約',
#  '野手',
#  '王威晨',
#  '投手',
#  '李振昌',
#  '複數',
#  '年約',
#  '兄弟',
#  '新聞稿',
#  '球員',
#  '結果',
#  '薪資',
#  '中信',
#  '兄弟',
#  '球團',
#  '球員',
#  '球隊',
#  '兄弟',
#  '野手',
#  '許基宏',
#  '團隊',
#  '球團',
#  '規劃',
#  '兄弟',
#  '球團',
#  '許基宏',
#  '月薪',
#  '合約',
#  '共識',
#  '月薪',
#  '調幅',
#  '許基宏',
#  '中信',
#  '兄弟',
#  '能力',
#  '野手',
#  '王威晨',
#  '投手',
#  '李振昌',
#  '球團',
#  '複數年合約',
#  '王威晨',
#  '月薪',
#  '李振昌',
#  '月薪',
#  '團隊',
#  '球隊',
#  '學弟',
#  '正面',
#  '影響力',
#  '選秀',
#  '兄弟',
#  '曾頌恩',
#  '生涯',
#  '佳績',
#  '總冠軍賽',
#  '殊榮',
#  '年度',
#  '進步',
#  '獎」',
#  '兄弟',
#  '球團',
#  '曾頌恩',
#  '月薪',
#  '調幅',
#  '曾頌恩',
#  '表現',
#  '高峰',
#  '戰役',
#  '兄弟',
#  '後援防線',
#  '投手',
#  '呂彥青',
#  '吳俊偉',
#  '呂彥青',
#  '月薪',
#  '調幅',
#  '吳俊偉',
#  '月薪',
#  '調幅',
#  '野手',
#  '岳東華',
#  '月薪',
#  '調幅',
#  '野手',
#  '岳政華',
#  '月薪',
#  '調幅',
#  '捕手',
#  '高宇杰',
#  '月薪',
#  '調幅',
#  '野手',
#  '王政順',
#  '月薪',
#  '調幅',
#  '捕手',
#  '林吳晉瑋',
#  '月薪',
#  '調幅',
#  '投手',
#  '謝榮豪',
#  '月薪',
#  '調幅',
#  '投手',
#  '黃恩賜',
#  '月薪',
#  '調幅',
#  '投手',
#  '魏碩成',
#  '月薪',
#  '調幅',
#  '野手',
#  '宋晟睿',
#  '兄弟',
#  '球團',
#  '選手',
#  '球員',
#  '投手',
#  '鄭浩均',
#  '月薪',
#  '吳哲源',
#  '月薪',
#  '楊志龍',
#  '月薪',
#  '江忠城',
#  '月薪',
#  '美國',
#  '職棒',
#  '奧克蘭',
#  '運動家隊',
#  '大聯盟',
#  '春訓',
#  '名單',
#  '球員',
#  '台灣',
#  '投手',
#  '莊陳仲敖',
#  '捕手',
#  '林家正',
#  '球員',
#  '春訓',
#  '投手',
#  '莊陳仲敖',
#  '世界',
#  '棒球',
#  '經典賽',
#  '資格賽',
#  '台灣',
#  '代表隊',
#  '成員',
#  '西班牙',
#  '關鍵',
#  '安打',
#  '台灣',
#  '莊陳仲敖',
#  '莊陳仲敖',
#  '資格賽',
#  '大聯盟',
#  '春訓',
#  '紀錄',
#  '聯盟',
#  '春訓',
#  '莊陳仲敖',
#  '層級',
#  '聯盟',
#  '戰績',
#  '防禦率',
#  '捕手',
#  '林家正',
#  '世界',
#  '棒球賽',
#  '世界',
#  '棒球',
#  '經典賽',
#  '資格賽',
#  '名單',
#  '運動家隊',
#  '大聯盟',
#  '春訓',
#  '資格賽',
#  '台灣隊',
#  '林家正',
#  '大聯盟',
#  '春訓',
#  '身賽',
#  '安打',
#  '林家正',
#  '層級',
#  '聯盟',
#  '打數',
#  '安打',
#  '全壘打',
#  '打擊率',
#  '運動家隊',
#  '大聯盟',
#  '春訓',
#  '名單',
#  '球員',
#  '球員',
#  '台灣',
#  '球員',
#  '莊陳仲敖',
#  '林家正']

# %%
list(top_cate_words.items())
# Out:
# [('政治',
#   [('台灣', 45),
#    ('咖啡', 28),
#    ('政府', 14),
#    ('瓜地馬拉', 9),
#    ('現金', 8),
#    ('教友', 7),
#    ('稅收', 7),
#    ('中國', 6),
#    ('瓜國', 6),
#    ('傅崐萁', 6),
#    ('中美洲', 5),
#    ('考察團', 5),
#    ('經濟', 5),
#    ('黨團', 5),
#    ('民眾黨', 5),
#    ('札尼', 4),
#    ('國家', 4),
#    ('布雷西亞', 4),
#    ('李世明', 4),
#    ('全球', 4)]),
#  ('科技',
#   [('火箭', 9),
#    ('星艦', 8),
#    ('市場', 7),
#    ('方案', 7),
#    ('太空', 7),
#    ('印度', 6),
#    ('衛星', 6),
#    ('企業', 5),
#    ('雲達', 5),
#    ('科技', 5),
#    ('歐洲', 5),
#    ('美國', 5),
#    ('時間', 5),
#    ('法國', 5),
#    ('產業', 4),
#    ('額度', 4),
#    ('機器人', 4),
#    ('技術', 4),
#    ('目標', 4),
#    ('規範', 3)]),
#  ('運動',
#   [('月薪', 20),
#    ('調幅', 13),
#    ('球員', 10),
#    ('兄弟', 10),
#    ('投手', 9),
#    ('野手', 8),
#    ('合約', 8),
#    ('球團', 8),
#    ('春訓', 7),
#    ('莊陳仲敖', 6),
#    ('陳傑憲', 5),
#    ('公司', 5),
#    ('台灣', 5),
#    ('選手', 5),
#    ('大聯盟', 5),
#    ('林家正', 5),
#    ('聲明', 4),
#    ('負責人', 4),
#    ('許基宏', 4),
#    ('捕手', 4)]),
#  ('全部',
#   [('台灣', 53),
#    ('咖啡', 28),
#    ('月薪', 20),
#    ('政府', 14),
#    ('調幅', 13),
#    ('市場', 11),
#    ('球員', 10),
#    ('兄弟', 10),
#    ('瓜地馬拉', 9),
#    ('火箭', 9),
#    ('投手', 9),
#    ('現金', 8),
#    ('方案', 8),
#    ('星艦', 8),
#    ('野手', 8),
#    ('合約', 8),
#    ('球團', 8),
#    ('教友', 7),
#    ('美國', 7),
#    ('稅收', 7)])]

# %% [markdown]
# ## Concatenate two list

# %%
row0 = df.iloc[0].token_pos
row0
# Out:
# "[('梵蒂岡', 'Nc'), ('宗座', 'Na'), ('圖書館', 'Nc'), ('總', 'Nc'), ('館長', 'Na'), ('札尼', 'Nb'), ('今天', 'Nd'), ('率領', 'VF'), ('數十', 'Neu'), ('位', 'Nf'), ('北義', 'Nc'), ('的', 'DE'), ('社會', 'Na'), ('菁英', 'Na'), ('教友', 'Na'), ('拜會', 'VC'), ('駐', 'VCL'), ('教廷', 'Nc'), ('大使館', 'Nc'), ('。', 'PERIODCATEGORY'), ('曾', 'D'), ('訪', 'VC'), ('台', 'Nc'), ('的', 'DE'), ('札尼', 'Nb'), ('致詞', 'VA'), ('時', 'Ng'), ('向', 'P'), ('教友', 'Na'), ('力', 'VC'), ('推', 'VC'), ('「', 'PARENTHESISCATEGORY'), ('台灣', 'Nc'), ('是', 'SHI'), ('個', 'Nf'), ('卓越', 'VH'), ('國家', 'Na'), ('，', 'COMMACATEGORY'), ('非常', 'Dfa'), ('值得', 'VH'), ('前往', 'VCL'), ('」', 'PARENTHESISCATEGORY'), ('，', 'COMMACATEGORY'), ('多', 'Neqa'), ('位', 'Nf'), ('教友', 'Na'), ('對', 'P'), ('台灣', 'Nc'), ('高度', 'A'), ('好奇', 'VH'), ('，', 'COMMACATEGORY'), ('熱情', 'VH'), ('表示', 'VE'), ('「', 'PARENTHESISCATEGORY'), ('下', 'Nes'), ('次', 'Nf'), ('旅遊', 'Nv'), ('地點', 'Na'), ('將', 'D'), ('鎖定', 'VC'), ('台灣', 'Nc'), ('」', 'PARENTHESISCATEGORY'), ('。', 'PERIODCATEGORY'), ('札尼', 'Nb'), ('（', 'PARENTHESISCATEGORY'), ('Angelo Vincenzo', 'FW'), (' Zani', 'FW'), ('）', 'PARENTHESISCATEGORY'), ('於', 'P'), ('2023年', 'Neu'), ('曾', 'D'), ('訪', 'VC'), ('台', 'Nc'), ('參加', 'VC'), ('故宮', 'Nc'), ('「', 'PARENTHESISCATEGORY'), ('梵蒂岡', 'Nb'), ('宗座', 'Nb'), ('圖書館', 'Nc'), ('珍藏', 'VC'), ('」', 'PARENTHESISCATEGORY'), ('暨', 'Caa'), ('「', 'PARENTHESISCATEGORY'), ('明清', 'Nd'), ('宮廷', 'Nc'), ('藏書', 'Na'), ('」', 'PARENTHESISCATEGORY'), ('特展', 'Na'), ('，', 'COMMACATEGORY'), ('對', 'P'), ('台灣', 'Nc'), ('留下', 'VC'), ('深刻', 'VH'), ('印象', 'Na'), ('。', 'PERIODCATEGORY'), ('他', 'Nh'), ('今天', 'Nd'), ('率領', 'VF'), ('北義', 'Nc'), ('家鄉', 'Nc'), ('布雷西亞', 'Nc'), ('（', 'PARENTHESISCATEGORY'), ('Brescia', 'FW'), ('）', 'PARENTHESISCATEGORY'), ('約', 'Da'), ('40', 'Neu'), ('位', 'Nf'), ('教友', 'Na'), ('到', 'VCL'), ('羅馬', 'Nc'), ('朝聖', 'VA'), ('，', 'COMMACATEGORY'), ('特別', 'VH'), ('安', 'VE'), ('排教友', 'VC'), ('參觀', 'VC'), ('台灣', 'Nc'), ('使館', 'Nc'), ('。', 'PERIODCATEGORY'), ('這', 'Nep'), ('群', 'Nf'), ('教友', 'Na'), ('皆', 'D'), ('為', 'VG'), ('布雷西亞', 'Nc'), ('扶輪社', 'Nc'), ('成員', 'Na'), ('，', 'COMMACATEGORY'), ('職業', 'Na'), ('包括', 'VK'), ('中', 'Na'), ('小企業家', 'VH'), ('、', 'PAUSECATEGORY'), ('大學', 'Nc'), ('教授', 'Na'), ('、', 'PAUSECATEGORY'), ('律師', 'Na'), ('和', 'Caa'), ('高階', 'A'), ('憲警', 'Na'), ('等', 'Cab'), ('。', 'PERIODCATEGORY'), ('札尼', 'Nb'), ('致詞', 'VA'), ('時', 'Ng'), ('盛讚', 'VE'), ('，', 'COMMACATEGORY'), ('台灣', 'Nc'), ('長期', 'Nd'), ('與', 'P'), ('教廷', 'Nc'), ('攜手', 'D'), ('推動', 'VC'), ('人道', 'Na'), ('援助', 'Na'), ('，', 'COMMACATEGORY'), ('包括', 'VK'), ('協助', 'VC'), ('他', 'Nh'), ('在', 'P'), ('非洲', 'Nc'), ('剛果', 'Nc'), ('推動', 'VC'), ('的', 'DE'), ('教育', 'Na'), ('與', 'Caa'), ('醫療', 'VC'), ('工作', 'Na'), ('，', 'COMMACATEGORY'), ('在COVID-19', 'P'), ('（', 'PARENTHESISCATEGORY'), ('2019', 'Neu'), ('冠狀', 'Na'), ('病毒', 'Na'), ('疾病', 'Na'), ('）', 'PARENTHESISCATEGORY'), ('疫情', 'Na'), ('期間', 'Na'), ('，', 'COMMACATEGORY'), ('台灣', 'Nc'), ('也', 'D'), ('曾', 'D'), ('向', 'P'), ('布雷西亞', 'Nc'), ('醫院', 'Nc'), ('捐贈', 'VD'), ('呼吸器', 'Na'), ('，', 'COMMACATEGORY'), ('因此', 'Cbb'), ('他', 'Nh'), ('一直', 'D'), ('想', 'VE'), ('向', 'P'), ('家鄉教友', 'Nc'), ('介紹', 'VE'), ('開放', 'VH'), ('、', 'PAUSECATEGORY'), ('多元', 'VH'), ('又', 'Caa'), ('好客', 'VH'), ('的', 'DE'), ('台灣', 'Nc'), ('，', 'COMMACATEGORY'), ('盼', 'VK'), ('促進', 'VK'), ('彼此', 'Nh'), ('更', 'Neqa'), ('多', 'VH'), ('交流', 'VH'), ('機會', 'Na'), ('。', 'PERIODCATEGORY'), ('駐', 'VCL'), ('教廷', 'Nc'), ('大使', 'Na'), ('李世明', 'Nb'), ('致詞', 'VA'), ('介紹', 'VE'), ('台灣', 'Nc'), ('時', 'Ng'), ('，', 'COMMACATEGORY'), ('引用', 'VC'), ('「', 'PARENTHESISCATEGORY'), ('時事哏', 'Na'), ('」', 'PARENTHESISCATEGORY'), ('開場', 'VA'), ('博', 'VJ'), ('得', 'DE'), ('眾人鼓掌大笑', 'Na'), ('。', 'PERIODCATEGORY'), ('他', 'Nh'), ('表示', 'VE'), ('，', 'COMMACATEGORY'), ('日前', 'Nd'), ('美國', 'Nc'), ('總統', 'Na'), ('川普', 'Nb'), ('（', 'PARENTHESISCATEGORY'), ('Donald', 'FW'), (' Trump', 'FW'), ('）', 'PARENTHESISCATEGORY'), ('與', 'P'), ('烏克蘭', 'Nc'), ('總統', 'Na'), ('澤倫斯基', 'Nb'), ('（', 'PARENTHESISCATEGORY'), ('Volody ...

# %%
type(row0)
# Out:
# str

# %%
row0 = eval(df.iloc[0].token_pos)
len(row0)
# Out:
# 492

# %%
row0
# Out:
# [('梵蒂岡', 'Nc'),
#  ('宗座', 'Na'),
#  ('圖書館', 'Nc'),
#  ('總', 'Nc'),
#  ('館長', 'Na'),
#  ('札尼', 'Nb'),
#  ('今天', 'Nd'),
#  ('率領', 'VF'),
#  ('數十', 'Neu'),
#  ('位', 'Nf'),
#  ('北義', 'Nc'),
#  ('的', 'DE'),
#  ('社會', 'Na'),
#  ('菁英', 'Na'),
#  ('教友', 'Na'),
#  ('拜會', 'VC'),
#  ('駐', 'VCL'),
#  ('教廷', 'Nc'),
#  ('大使館', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('曾', 'D'),
#  ('訪', 'VC'),
#  ('台', 'Nc'),
#  ('的', 'DE'),
#  ('札尼', 'Nb'),
#  ('致詞', 'VA'),
#  ('時', 'Ng'),
#  ('向', 'P'),
#  ('教友', 'Na'),
#  ('力', 'VC'),
#  ('推', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('台灣', 'Nc'),
#  ('是', 'SHI'),
#  ('個', 'Nf'),
#  ('卓越', 'VH'),
#  ('國家', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('非常', 'Dfa'),
#  ('值得', 'VH'),
#  ('前往', 'VCL'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('多', 'Neqa'),
#  ('位', 'Nf'),
#  ('教友', 'Na'),
#  ('對', 'P'),
#  ('台灣', 'Nc'),
#  ('高度', 'A'),
#  ('好奇', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('熱情', 'VH'),
#  ('表示', 'VE'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('下', 'Nes'),
#  ('次', 'Nf'),
#  ('旅遊', 'Nv'),
#  ('地點', 'Na'),
#  ('將', 'D'),
#  ('鎖定', 'VC'),
#  ('台灣', 'Nc'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('。', 'PERIODCATEGORY'),
#  ('札尼', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Angelo Vincenzo', 'FW'),
#  (' Zani', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('於', 'P'),
#  ('2023年', 'Neu'),
#  ('曾', 'D'),
#  ('訪', 'VC'),
#  ('台', 'Nc'),
#  ('參加', 'VC'),
#  ('故宮', 'Nc'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('梵蒂岡', 'Nb'),
#  ('宗座', 'Nb'),
#  ('圖書館', 'Nc'),
#  ('珍藏', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('暨', 'Caa'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('明清', 'Nd'),
#  ('宮廷', 'Nc'),
#  ('藏書', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('特展', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('對', 'P'),
#  ('台灣', 'Nc'),
#  ('留下', 'VC'),
#  ('深刻', 'VH'),
#  ('印象', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('他', 'Nh'),
#  ('今天', 'Nd'),
#  ('率領', 'VF'),
#  ('北義', 'Nc'),
#  ('家鄉', 'Nc'),
#  ('布雷西亞', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Brescia', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('約', 'Da'),
#  ('40', 'Neu'),
#  ('位', 'Nf'),
#  ('教友', 'Na'),
#  ('到', 'VCL'),
#  ('羅馬', 'Nc'),
#  ('朝聖', 'VA'),
#  ('，', 'COMMACATEGORY'),
#  ('特別', 'VH'),
#  ('安', 'VE'),
#  ('排教友', 'VC'),
#  ('參觀', 'VC'),
#  ('台灣', 'Nc'),
#  ('使館', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('這', 'Nep'),
#  ('群', 'Nf'),
#  ('教友', 'Na'),
#  ('皆', 'D'),
#  ('為', 'VG'),
#  ('布雷西亞', 'Nc'),
#  ('扶輪社', 'Nc'),
#  ('成員', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('職業', 'Na'),
#  ('包括', 'VK'),
#  ('中', 'Na'),
#  ('小企業家', 'VH'),
#  ('、', 'PAUSECATEGORY'),
#  ('大學', 'Nc'),
#  ('教授', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('律師', 'Na'),
#  ('和', 'Caa'),
#  ('高階', 'A'),
#  ('憲警', 'Na'),
#  ('等', 'Cab'),
#  ('。', 'PERIODCATEGORY'),
#  ('札尼', 'Nb'),
#  ('致詞', 'VA'),
#  ('時', 'Ng'),
#  ('盛讚', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('長期', 'Nd'),
#  ('與', 'P'),
#  ('教廷', 'Nc'),
#  ('攜手', 'D'),
#  ('推動', 'VC'),
#  ('人道', 'Na'),
#  ('援助', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('包括', 'VK'),
#  ('協助', 'VC'),
#  ('他', 'Nh'),
#  ('在', 'P'),
#  ('非洲', 'Nc'),
#  ('剛果', 'Nc'),
#  ('推動', 'VC'),
#  ('的', 'DE'),
#  ('教育', 'Na'),
#  ('與', 'Caa'),
#  ('醫療', 'VC'),
#  ('工作', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('在COVID-19', 'P'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('2019', 'Neu'),
#  ('冠狀', 'Na'),
#  ('病毒', 'Na'),
#  ('疾病', 'Na'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('疫情', 'Na'),
#  ('期間', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('也', 'D'),
#  ('曾', 'D'),
#  ('向', 'P'),
#  ('布雷西亞', 'Nc'),
#  ('醫院', 'Nc'),
#  ('捐贈', 'VD'),
#  ('呼吸器', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('因此', 'Cbb'),
#  ('他', 'Nh'),
#  ('一直', 'D'),
#  ('想', 'VE'),
#  ('向', 'P'),
#  ('家鄉教友', 'Nc'),
#  ('介紹', 'VE'),
#  ('開放', 'VH'),
#  ('、', 'PAUSECATEGORY'),
#  ('多元', 'VH'),
#  ('又', 'Caa'),
#  ('好客', 'VH'),
#  ('的', 'DE'),
#  ('台灣', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('盼', 'VK'),
#  ('促進', 'VK'),
#  ('彼此', 'Nh'),
#  ('更', 'Neqa'),
#  ('多', 'VH'),
#  ('交流', 'VH'),
#  ('機會', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('駐', 'VCL'),
#  ('教廷', 'Nc'),
#  ('大使', 'Na'),
#  ('李世明', 'Nb'),
#  ('致詞', 'VA'),
#  ('介紹', 'VE'),
#  ('台灣', 'Nc'),
#  ('時', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('引用', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('時事哏', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('開場', 'VA'),
#  ('博', 'VJ'),
#  ('得', 'DE'),
#  ('眾人鼓掌大笑', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('他', 'Nh'),
#  ('表示', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('日前', 'Nd'),
#  ('美國', 'Nc'),
#  ('總統', 'Na'),
#  ('川普', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Donald', 'FW'),
#  (' Trump', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('與', 'P'),
#  ('烏克蘭', 'Nc'),
#  ('總統', 'Na'),
#  ('澤倫斯基', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Volodymyr Zelenskyy', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('在', 'P'),
#  ('白宮', 'Nc'),
#  ('會晤', 'VC'),
#  ('後', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('有', 'V_2'),
#  ('句', 'Nf'),
#  ('流行語', 'Na'),
#  ('在', 'P'),
#  ('國際社會', 'Nc'),
#  ('很', 'Dfa'),
#  ('夯', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('就是', 'Cbb'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('你', 'Nh'),
#  ('手', 'Na'),
#  ('上', 'Ncd'),
#  ('有', 'V_2'),
#  ('什麼', 'Nep'),
#  ('牌', 'Na'),
#  ('可', 'D'),
#  ('打', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Na'),
#  ('論', 'VC'),
#  ('領土', 'Na'),
#  ('面積', 'Na'),
#  ('雖', 'Cbb'),
#  ('小', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('但', 'Cbb'),
#  ('台灣', 'Nc'),
#  ('對', 'P'),
#  ('國際', 'Nc'),
#  ('很', 'Dfa'),
#  ('重要', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('可', 'D'),
#  ('說', 'VE'),
#  ('手', 'Na'),
#  ('上', 'Ncd'),
#  ('有', 'V_2'),
#  ('很多', 'Neqa'),
#  ('牌', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('其', 'Nep'),
#  ('重要性', 'Na'),
#  ('可', 'D'),
#  ('分', 'VC'),
#  ('3', 'Neu'),
#  ('個', 'Nf'),
#  ('主要', 'A'),
#  ('方面', 'Na'),
#  ('闡釋', 'VC'),
#  ('。', 'PERIODCATEGORY'),
#  ('李世明', 'Nb'),
#  ('說', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('首先', 'D'),
#  ('台灣', 'Nc'),
#  ('具有', 'VJ'),
#  ('地緣', 'Na'),
#  ('戰略', 'Na'),
#  ('重要性', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('海峽', 'Na'),
#  ('是', 'SHI'),
#  ('全球', 'Nc'),
#  ('貨運', 'Na'),
#  ('通過', 'VC'),
#  ('的', 'DE'),
#  ('重要', 'VH'),
#  ('管道', 'Na'),
#  ('；', 'SEMICOLONCATEGORY'),
#  ('第二', 'Neu'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('半導體', 'Na'),
#  ('產業', 'Na'),
#  ('位居', 'VCL'),
#  ('世界', 'Nc'),
#  ('關鍵', 'Na'),
#  ('地位', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('先進', 'VH'),
#  ('晶片', 'Na'),
#  ('製程', 'Na'),
#  ('在', 'P'),
#  ('全球', 'Nc'),
#  ('市占率', 'Na'),
#  ('超過', 'VJ'),
#  ('9成', 'Neqa'),
#  ('。', 'PERIODCATEGORY'),
#  ('李世明', 'Nb'),
#  ('表示', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('第三', 'Neu'),
#  ('點', 'Nf'),
#  ('最', 'Dfa'),
#  ('重要', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('教宗方', 'Na'),
#  ('濟各', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Pope', 'FW'),
#  (' ', 'WHITESPACE'),
#  ('Francis', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('說', 'VE'),
#  ('今年', 'Nd'),
#  ('是', 'SHI'),
#  ('希望', 'VK'),
#  ('禧年', 'Nd'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('作為', 'VG'),
#  ('自由', 'VH'),
#  ('民主', 'VH'),
#  ('國家', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('是', 'SHI'),
#  ('所有', 'Neqa'),
#  ('受到', 'VJ'),
#  ('中國', 'Nc'),
#  ('共產', 'A'),
#  ('威權', 'Na'),
#  ('統治', 'VC'),
#  ('下', 'Ng'),
#  ('人民', 'Na'),
#  ('的', 'DE'),
#  ('希望', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('因為', 'Cbb'),
#  ('在', 'P'),
#  ('中國', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('人民', 'Na'),
#  ('無法', 'D'),
#  ('享受', 'VJ'),
#  ('自由', 'Na'),
#  ('與', 'Caa'),
#  ('公平', 'VH'),
#  ('正義', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('台灣', 'Nc'),
#  ('扮演', 'VC'),
#  ('了', 'Di'),
#  ('帶來', 'VC'),
#  ('希望', 'Na'),
#  ('的', 'DE'),
#  ('角色', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('。', 'PERIODCATEGORY'),
#  ('李世明', 'Nb'),
#  ('鼓勵', 'VF'),
#  ('北義菁英', 'Nb'),
#  ('教友', 'Na'),
#  ('到', 'VCL'),
#  ('台灣', 'Nc'),
#  ('訪問', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('現', 'Nd'),
#  ('在', 'P'),
#  ('羅馬', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('米蘭', 'Nc'),
#  ('都', 'D'),
#  ('有', 'V_2'),
#  ('直飛', 'VCL'),
#  ('台灣', 'Nc'),
#  ('班機', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('非常', 'Dfa'),
#  ('方便', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('在', 'VA'),
#  ('場', 'Nc'),
#  ('的', 'DE'),
#  ('布雷西亞', 'Nc'),
#  ('扶輪社', 'Nc'),
#  ('幹部', 'Na'),
#  ('對', 'P'),
#  ('此', 'Nep'),
#  ('反應', 'Na'),
#  ('熱烈', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('當場', 'D'),
#  ('表示', 'VE'),
#  ('要', 'D'),
#  ('公開', 'VHC'),
#  ('徵求', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('台灣', 'Nc'),
#  ('扶輪社', 'Nc'),
#  ('姊妹社', 'Nc'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('下', 'Nes'),
#  ('次', 'Nf'),
#  ('立刻', 'D'),
#  ('安排', 'VE'),
#  ('整團', 'Neqa'),
#  ('訪', 'VC'),
#  ('台', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('不少', 'Neqa'),
#  ('教友', 'Na'),
#  ('也', 'D'),
#  ('直', 'D'),
#  ('喊', 'VE'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('報名', 'VA'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('、', 'PAUSECATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('加', 'VC'),
#  ('一', 'Neu'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('開始', 'VL'),
#  ('向', 'P'),
#  ('使館', 'Nc'),
#  ('人員', 'Na'),
#  ('打探', 'VC'),
#  ('台灣', 'Nc'),
#  ('有', 'V_2'),
#  ('哪些', 'Neqa'),
#  ('美食', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('登山', 'VA'),
#  ('、', 'PAUSECATEGORY'),
#  ('海灘', 'Na'),
#  ('景點', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('展現', 'VC'),
#  ('義大利人', 'Na'),
#  ('熱情', 'VH'),
#  ('的', 'DE'),
#  ('民族性', 'Na'),
#  ('。', 'PERIODCATEGORY')]

# %%
row1 = eval(df.iloc[1].token_pos)

# %%
row1
# Out:
# [('由', 'P'),
#  ('外交部', 'Nc'),
#  ('中美洲', 'Nc'),
#  ('經貿', 'Na'),
#  ('辦事處', 'Nc'),
#  ('籌組', 'VC'),
#  ('的', 'DE'),
#  ('台灣', 'Nc'),
#  ('咖啡', 'Na'),
#  ('考察團', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('力挺', 'VC'),
#  ('友邦', 'Nc'),
#  ('瓜地馬拉', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('預計', 'VE'),
#  ('採購', 'VC'),
#  ('38', 'Neu'),
#  ('個', 'Nf'),
#  ('貨櫃', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('72萬', 'Neu'),
#  ('公斤', 'Nf'),
#  ('咖啡', 'Na'),
#  ('生豆', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('除', 'P'),
#  ('比', 'P'),
#  ('去年', 'Nd'),
#  ('增加', 'VHC'),
#  ('近', 'Nes'),
#  ('5成', 'Neqa'),
#  ('，', 'COMMACATEGORY'),
#  ('考察團', 'Na'),
#  ('規模', 'Na'),
#  ('和', 'Caa'),
#  ('採購量', 'Na'),
#  ('更', 'Dfa'),
#  ('創下', 'VC'),
#  ('歷年', 'Nd'),
#  ('新高', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('台灣', 'Nc'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('2025年', 'Neu'),
#  ('中美洲', 'Nc'),
#  ('咖啡', 'Na'),
#  ('經', 'Na'),
#  ('貿', 'Na'),
#  ('考察團', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('日前', 'Nd'),
#  ('抵達', 'VCL'),
#  ('瓜地馬拉', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('實地', 'D'),
#  ('考察', 'VC'),
#  ('咖啡', 'Na'),
#  ('生產', 'Na'),
#  ('鏈', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('3日', 'Nd'),
#  ('上午', 'Nd'),
#  ('也', 'D'),
#  ('前往', 'VCL'),
#  ('瓜地馬拉', 'Nc'),
#  ('咖啡', 'Nc'),
#  ('協會', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('ANACAFE', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('拜訪', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('並且', 'Cbb'),
#  ('親身', 'Na'),
#  ('杯測', 'Na'),
#  ('瓜國', 'Nc'),
#  ('各', 'Nes'),
#  ('個', 'Nf'),
#  ('產區', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('不同', 'VH'),
#  ('品種', 'Na'),
#  ('風味', 'Na'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('中美洲', 'Nc'),
#  ('經貿', 'Na'),
#  ('辦事處', 'Nc'),
#  ('主任', 'Na'),
#  ('徐韶慧', 'Nb'),
#  ('表示', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('相較', 'VB'),
#  ('去年', 'Nd'),
#  ('1', 'Neu'),
#  ('1', 'Neu'),
#  ('家', 'Nf'),
#  ('台灣', 'Nc'),
#  ('業者', 'Na'),
#  ('組團', 'VA'),
#  ('考察', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('下單', 'Na'),
#  ('採購', 'VC'),
#  ('總價值', 'Na'),
#  ('260萬', 'Neu'),
#  ('美元', 'Nf'),
#  ('，', 'COMMACATEGORY'),
#  ('26', 'Neu'),
#  ('個', 'Nf'),
#  ('貨櫃', 'Na'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('生豆', 'VC'),
#  ('；', 'SEMICOLONCATEGORY'),
#  ('今年', 'Nd'),
#  ('增加到', 'VHC'),
#  ('1', 'Neu'),
#  ('3', 'Neu'),
#  ('家', 'Nf'),
#  ('台灣', 'Nc'),
#  ('業者', 'Na'),
#  ('參與', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('更', 'Dfa'),
#  ('大幅', 'D'),
#  ('採購', 'VC'),
#  ('總計', 'Da'),
#  ('38', 'Neu'),
#  ('個', 'Nf'),
#  ('貨櫃', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('共', 'Da'),
#  ('72萬', 'Neu'),
#  ('公斤', 'Nf'),
#  ('咖啡', 'Na'),
#  ('生', 'VC'),
#  ('豆', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('顯示', 'VK'),
#  ('台灣', 'Nc'),
#  ('消費者', 'Na'),
#  ('對', 'P'),
#  ('瓜地馬拉', 'Nc'),
#  ('咖啡', 'Na'),
#  ('的', 'DE'),
#  ('喜愛', 'Nv'),
#  ('，', 'COMMACATEGORY'),
#  ('更', 'Dfa'),
#  ('凸顯', 'VJ'),
#  ('台', 'Nc'),
#  ('瓜', 'Nc'),
#  ('蓬勃商機', 'VH'),
#  ('發展', 'VC'),
#  ('。', 'PERIODCATEGORY'),
#  ('徐韶慧', 'Nb'),
#  ('強調', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('根據', 'P'),
#  ('統計', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('2024年', 'Neu'),
#  ('瓜地馬拉', 'Nc'),
#  ('進口', 'VC'),
#  ('的', 'DE'),
#  ('咖啡豆', 'Na'),
#  ('占', 'VJ'),
#  ('台灣', 'Nc'),
#  ('咖啡', 'Na'),
#  ('消費', 'Na'),
#  ('總量', 'Na'),
#  ('的', 'DE'),
#  ('10%', 'Neqa'),
#  ('以上', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('是', 'SHI'),
#  ('台灣', 'Nc'),
#  ('第4', 'Neu'),
#  ('大', 'VH'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('進口國', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('換句', 'Dk'),
#  ('話', 'Na'),
#  ('說', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('每', 'D'),
#  ('賣', 'VC'),
#  ('出', 'VC'),
#  ('1', 'Neu'),
#  ('0', 'Neu'),
#  ('杯', 'Nf'),
#  ('咖啡', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('就', 'D'),
#  ('有', 'V_2'),
#  ('超過', 'VJ'),
#  ('1', 'Neu'),
#  ('杯', 'Nf'),
#  ('是', 'SHI'),
#  ('來自', 'VJ'),
#  ('瓜地馬拉', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('此外', 'Cbb'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('在', 'P'),
#  ('整', 'Neqa'),
#  ('個', 'Nf'),
#  ('亞洲', 'Nc'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('消費國中', 'Na'),
#  ('也', 'D'),
#  ('位居第3', 'VCL'),
#  ('，', 'COMMACATEGORY'),
#  ('僅', 'Da'),
#  ('次於', 'VJ'),
#  ('日本', 'Nc'),
#  ('和', 'Caa'),
#  ('韓國', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('去年', 'Nd'),
#  ('5月', 'Nd'),
#  ('底', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('中國', 'Nc'),
#  ('突然', 'D'),
#  ('宣布', 'VE'),
#  ('禁止', 'VE'),
#  ('瓜地馬拉', 'Nc'),
#  ('夏威夷豆', 'Nc'),
#  ('和', 'Caa'),
#  ('咖啡豆', 'Na'),
#  ('進口', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('作為', 'VG'),
#  ('外交', 'Na'),
#  ('勒索', 'Nv'),
#  ('手段', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('引起', 'VC'),
#  ('瓜國政府', 'Nc'),
#  ('和', 'Caa'),
#  ('業者', 'Na'),
#  ('不滿', 'VK'),
#  ('。', 'PERIODCATEGORY'),
#  ('台灣', 'Nc'),
#  ('外交部', 'Nc'),
#  ('和', 'Caa'),
#  ('台灣', 'Nc'),
#  ('咖啡', 'Na'),
#  ('進口商', 'Na'),
#  ('第一', 'Neu'),
#  ('時間', 'Na'),
#  ('伸出', 'VC'),
#  ('援手', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('將', 'P'),
#  ('這', 'Nep'),
#  ('一', 'Neu'),
#  ('批', 'Nf'),
#  ('咖啡貨櫃', 'Na'),
#  ('轉運往', 'VCL'),
#  ('台灣', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('中美洲', 'Nc'),
#  ('經貿', 'Na'),
#  ('辦事處', 'Nc'),
#  ('也', 'D'),
#  ('別出心裁', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('將', 'P'),
#  ('這', 'Nep'),
#  ('批', 'Nf'),
#  ('瓜國', 'Nc'),
#  ('咖啡', 'Na'),
#  ('豆', 'Na'),
#  ('製作成', 'VG'),
#  ('濾掛式', 'A'),
#  ('咖啡包', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('在', 'P'),
#  ('此', 'Nep'),
#  ('次', 'Nf'),
#  ('參訪', 'VC'),
#  ('行程', 'Na'),
#  ('更', 'Dfa'),
#  ('將', 'D'),
#  ('致贈', 'VD'),
#  ('瓜國', 'Nc'),
#  ('友人', 'Na'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('限定版', 'Na'),
#  ('友誼', 'Na'),
#  ('咖啡', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('禮盒', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('成為', 'VG'),
#  ('台灣', 'Nc'),
#  ('力挺', 'VC'),
#  ('瓜國', 'Nc'),
#  ('另', 'Nes'),
#  ('一', 'Neu'),
#  ('種', 'Nf'),
#  ('象徵', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('根據', 'P'),
#  ('瓜地', 'Nc'),
#  ('馬拉', 'Na'),
#  ('中央', 'Nc'),
#  ('銀行', 'Nc'),
#  ('數據', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('2024年', 'Neu'),
#  ('瓜地', 'Nc'),
#  ('馬拉', 'Na'),
#  ('對', 'P'),
#  ('台灣', 'Nc'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('出口', 'VC'),
#  ('超過', 'VJ'),
#  ('1800萬', 'Neu'),
#  ('美元', 'Nf'),
#  ('，', 'COMMACATEGORY'),
#  ('相比於', 'VB'),
#  ('2023年', 'Neu'),
#  ('，', 'COMMACATEGORY'),
#  ('出口量', 'Na'),
#  ('增長', 'VHC'),
#  ('了', 'Di'),
#  ('13%', 'Neqa'),
#  ('；', 'SEMICOLONCATEGORY'),
#  ('而', 'Cbb'),
#  ('咖啡', 'Na'),
#  ('也', 'D'),
#  ('僅', 'Da'),
#  ('次於', 'VJ'),
#  ('糖', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('成為', 'VG'),
#  ('瓜國', 'Nc'),
#  ('出口', 'VC'),
#  ('台灣', 'Nc'),
#  ('的', 'DE'),
#  ('第二', 'Neu'),
#  ('大', 'VH'),
#  ('商品', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('出席', 'Nv'),
#  ('活動', 'Na'),
#  ('的', 'DE'),
#  ('瓜地', 'Nc'),
#  ('馬拉', 'Na'),
#  ('外交部', 'Nc'),
#  ('次長', 'Na'),
#  ('歐洛斯柯', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Julio Orozco', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('特別', 'VH'),
#  ('感謝', 'VK'),
#  ('台灣', 'Nc'),
#  ('和', 'Caa'),
#  ('瓜地馬拉', 'Nc'),
#  ('共同', 'A'),
#  ('推廣', 'VC'),
#  ('咖啡', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('不只', 'Da'),
#  ('進', 'D'),
#  ('一', 'Neu'),
#  ('步', 'Nf'),
#  ('提升', 'VC'),
#  ('全球', 'Nc'),
#  ('市場', 'Nc'),
#  ('地位', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('更', 'Dfa'),
#  ('讓', 'VL'),
#  ('台瓜人民', 'Nc'),
#  ('及', 'Caa'),
#  ('瓜國', 'Nc'),
#  ('咖啡', 'Na'),
#  ('農', 'Na'),
#  ('都', 'D'),
#  ('能夠', 'D'),
#  ('受惠', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('除了', 'P'),
#  ('政治', 'Na'),
#  ('因素', 'Na'),
#  ('干擾', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('近年來', 'Nd'),
#  ('全球', 'Nc'),
#  ('咖啡', 'Na'),
#  ('受到', 'VJ'),
#  ('氣候', 'Na'),
#  ('變遷', 'VH'),
#  ('影響', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('產量', 'Na'),
#  ('供應', 'VD'),
#  ('不', 'D'),
#  ('穩', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('市場', 'Nc'),
#  ('價格', 'Na'),
#  ('也', 'D'),
#  ('大幅', 'D'),
#  ('波動', 'VAC'),
#  ('。', 'PERIODCATEGORY'),
#  ('台灣', 'Nc'),
#  ('咖啡', 'Na'),
#  ('考察團', 'Na'),
#  ('業者', 'Na'),
#  ('張正仁', 'Nb'),
#  ('指出', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('過', 'Nd'),
#  ('去', 'VJ'),
#  ('咖啡', 'Na'),
#  ('價格', 'Na'),
#  ('雖然', 'Cbb'),
#  ('每', 'Nes'),
#  ('十', 'Neu'),
#  ('年', 'Nf'),
#  ('就', 'D'),
#  ('會', 'D'),
#  ('有', 'V_2'),
#  ('一', 'Neu'),
#  ('次', 'Nf'),
#  ('上漲', 'Nv'),
#  ('，', 'COMMACATEGORY'),
#  ('但', 'Cbb'),
#  ('基本', 'Na'),
#  ('上', 'Ng'),
#  ('2', 'Neu'),
#  ('、', 'PAUSECATEGORY'),
#  ('3', 'Neu'),
#  ('個', 'Nf'),
#  ('月', 'Na'),
#  ('後', 'Ng'),
#  ('就', 'D'),
#  ('恢復', 'VHC'),
#  ('平穩', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('不過', 'Cbb'),
#  ('自', 'P'),
#  ('COVID-19', 'FW'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('2019', 'Neu'),
#  ('冠狀', 'Na'),
#  ('病毒', 'Na'),
#  ('疾病', 'Na'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('疫情', 'Na'),
#  ('後', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('咖啡', 'Na'),
#  ('價格', 'Na'),
#  ('卻', 'D'),
#  ('持續', 'VL'),
#  ('走揚', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('這', 'Nep'),
#  ('種', 'Nf'),
#  ('情況', 'Na'),
#  ('是', 'SHI'),
#  ('過數十', 'VCL'),
#  ('年', 'Nf'),
#  ('罕見', 'VH'),
#  ('的', 'T'),
#  ('，', 'COMMACATEGORY'),
#  ('自然', 'D'),
#  ('也', 'D'),
#  ('造成', 'VK'),
#  ('進口商', 'Na'),
#  ('的', 'DE'),
#  ('成本', 'Na'),
#  ('壓力', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('張正仁', 'Nb'),
#  ('強調', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('現在', 'Nd'),
#  ('只能', 'Da'),
#  ('觀察', 'VE'),
#  ('3', 'Nd'),
#  ('、', 'PAUSECATEGORY'),
#  ('4', 'Nd'),
#  ('月', 'Na'),
#  ('後', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('全', 'Neqa'),
#  ('世界', 'Nc'),
#  ('第一', 'Neu'),
#  ('大', 'VH'),
#  ('咖啡', 'Na'),
#  ('生產國', 'Na'),
#  ('巴西', 'Nc'),
#  ('氣候', 'Na'),
#  ('是否', 'D'),
#  ('穩定', 'VHC'),
#  ('，', 'COMMACATEGORY'),
#  ('產量', 'Na'),
#  ('回穩', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('未來', 'Nd'),
#  ('咖啡', 'Na'),
#  ('價格', 'Na'),
#  ('波動', 'VAC'),
#  ('才', 'Da'),
#  ('會', 'D'),
#  ('明朗', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('中美洲', 'Nc'),
#  ('經貿', 'Na'),
#  ('辦', 'Nc'),
#  ('事處', 'Na'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('CATO', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('表示', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('瓜地馬拉', 'Nc'),
#  ('因', 'Cbb'),
#  ('地理', 'Na'),
#  ('條件', 'Na'),
#  ('與', 'Caa'),
#  ('多樣化', 'VHC'),
#  ('的', 'DE'),
#  ('微型', 'A'),
#  ('氣候', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('本身', 'Nh'),
#  ('擁有', 'VJ'),
#  ('8', 'Neu'),
#  ('大', 'VH'),
#  ('咖啡', 'Na'),
#  ('產區', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('其中', 'Nep'),
#  ('以', 'P'),
#  ('安', 'Nc'),
#  ('地瓜', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Antigua', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('與', 'Caa'),
#  ('維維特南戈', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Huehu', 'FW'),
#  ('etenango', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('尤', 'D'),
#  ('為', 'VG'),
#  ('出名', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('台灣', 'Nc'),
#  ('考察團', 'Na'),
#  ('此', 'Nep'),
#  ('次', 'Nf'),
#  ('也', 'D'),
#  ('將', 'D'),
#  ('深入', 'VH'),
#  ('位於', 'VCL'),
#  ('內陸', 'Nc'),
#  ('高海拔', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('地處', 'VJ'),
#  ('偏遠', 'VH'),
#  ('交通', 'Na'),
#  ('不便', 'VH'),
#  ('的', 'DE'),
#  ('維維特', 'Nb'),
#  ('南戈', 'Nc'),
#  ('產區', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('親自', 'D'),
#  ('探訪', 'VC'),
#  ('並', 'D'),
#  ('了解', 'VC'),
#  ('當地', 'Nc'),
#  ('咖啡', 'Na'),
#  ('從', 'P'),
#  ('種植', 'VC'),
#  ('、', 'PAUSECATEGORY'),
#  ('採收', 'VC'),
#  ('、', 'PAUSECATEGORY'),
#  ('處理', 'VC'),
#  ('到', 'P'),
#  ('烘焙', 'VC'),
#  ('的', 'DE'),
#  ('完整', 'VH'),
#  ('生產', 'Nv'),
#  ('流程', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('與', 'P'),
#  ('咖啡農', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('處理', 'Nc'),
#  ('廠', 'Nc'),
#  ('及', 'Caa'),
#  ('出口商', 'Na'),
#  ('交流', 'VH'),
#  ('。', 'PERIODCATEGORY')]

# %%
row01 = row0+row1

# %%
row01
# Out:
# [('梵蒂岡', 'Nc'),
#  ('宗座', 'Na'),
#  ('圖書館', 'Nc'),
#  ('總', 'Nc'),
#  ('館長', 'Na'),
#  ('札尼', 'Nb'),
#  ('今天', 'Nd'),
#  ('率領', 'VF'),
#  ('數十', 'Neu'),
#  ('位', 'Nf'),
#  ('北義', 'Nc'),
#  ('的', 'DE'),
#  ('社會', 'Na'),
#  ('菁英', 'Na'),
#  ('教友', 'Na'),
#  ('拜會', 'VC'),
#  ('駐', 'VCL'),
#  ('教廷', 'Nc'),
#  ('大使館', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('曾', 'D'),
#  ('訪', 'VC'),
#  ('台', 'Nc'),
#  ('的', 'DE'),
#  ('札尼', 'Nb'),
#  ('致詞', 'VA'),
#  ('時', 'Ng'),
#  ('向', 'P'),
#  ('教友', 'Na'),
#  ('力', 'VC'),
#  ('推', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('台灣', 'Nc'),
#  ('是', 'SHI'),
#  ('個', 'Nf'),
#  ('卓越', 'VH'),
#  ('國家', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('非常', 'Dfa'),
#  ('值得', 'VH'),
#  ('前往', 'VCL'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('多', 'Neqa'),
#  ('位', 'Nf'),
#  ('教友', 'Na'),
#  ('對', 'P'),
#  ('台灣', 'Nc'),
#  ('高度', 'A'),
#  ('好奇', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('熱情', 'VH'),
#  ('表示', 'VE'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('下', 'Nes'),
#  ('次', 'Nf'),
#  ('旅遊', 'Nv'),
#  ('地點', 'Na'),
#  ('將', 'D'),
#  ('鎖定', 'VC'),
#  ('台灣', 'Nc'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('。', 'PERIODCATEGORY'),
#  ('札尼', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Angelo Vincenzo', 'FW'),
#  (' Zani', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('於', 'P'),
#  ('2023年', 'Neu'),
#  ('曾', 'D'),
#  ('訪', 'VC'),
#  ('台', 'Nc'),
#  ('參加', 'VC'),
#  ('故宮', 'Nc'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('梵蒂岡', 'Nb'),
#  ('宗座', 'Nb'),
#  ('圖書館', 'Nc'),
#  ('珍藏', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('暨', 'Caa'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('明清', 'Nd'),
#  ('宮廷', 'Nc'),
#  ('藏書', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('特展', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('對', 'P'),
#  ('台灣', 'Nc'),
#  ('留下', 'VC'),
#  ('深刻', 'VH'),
#  ('印象', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('他', 'Nh'),
#  ('今天', 'Nd'),
#  ('率領', 'VF'),
#  ('北義', 'Nc'),
#  ('家鄉', 'Nc'),
#  ('布雷西亞', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Brescia', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('約', 'Da'),
#  ('40', 'Neu'),
#  ('位', 'Nf'),
#  ('教友', 'Na'),
#  ('到', 'VCL'),
#  ('羅馬', 'Nc'),
#  ('朝聖', 'VA'),
#  ('，', 'COMMACATEGORY'),
#  ('特別', 'VH'),
#  ('安', 'VE'),
#  ('排教友', 'VC'),
#  ('參觀', 'VC'),
#  ('台灣', 'Nc'),
#  ('使館', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('這', 'Nep'),
#  ('群', 'Nf'),
#  ('教友', 'Na'),
#  ('皆', 'D'),
#  ('為', 'VG'),
#  ('布雷西亞', 'Nc'),
#  ('扶輪社', 'Nc'),
#  ('成員', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('職業', 'Na'),
#  ('包括', 'VK'),
#  ('中', 'Na'),
#  ('小企業家', 'VH'),
#  ('、', 'PAUSECATEGORY'),
#  ('大學', 'Nc'),
#  ('教授', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('律師', 'Na'),
#  ('和', 'Caa'),
#  ('高階', 'A'),
#  ('憲警', 'Na'),
#  ('等', 'Cab'),
#  ('。', 'PERIODCATEGORY'),
#  ('札尼', 'Nb'),
#  ('致詞', 'VA'),
#  ('時', 'Ng'),
#  ('盛讚', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('長期', 'Nd'),
#  ('與', 'P'),
#  ('教廷', 'Nc'),
#  ('攜手', 'D'),
#  ('推動', 'VC'),
#  ('人道', 'Na'),
#  ('援助', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('包括', 'VK'),
#  ('協助', 'VC'),
#  ('他', 'Nh'),
#  ('在', 'P'),
#  ('非洲', 'Nc'),
#  ('剛果', 'Nc'),
#  ('推動', 'VC'),
#  ('的', 'DE'),
#  ('教育', 'Na'),
#  ('與', 'Caa'),
#  ('醫療', 'VC'),
#  ('工作', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('在COVID-19', 'P'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('2019', 'Neu'),
#  ('冠狀', 'Na'),
#  ('病毒', 'Na'),
#  ('疾病', 'Na'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('疫情', 'Na'),
#  ('期間', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('也', 'D'),
#  ('曾', 'D'),
#  ('向', 'P'),
#  ('布雷西亞', 'Nc'),
#  ('醫院', 'Nc'),
#  ('捐贈', 'VD'),
#  ('呼吸器', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('因此', 'Cbb'),
#  ('他', 'Nh'),
#  ('一直', 'D'),
#  ('想', 'VE'),
#  ('向', 'P'),
#  ('家鄉教友', 'Nc'),
#  ('介紹', 'VE'),
#  ('開放', 'VH'),
#  ('、', 'PAUSECATEGORY'),
#  ('多元', 'VH'),
#  ('又', 'Caa'),
#  ('好客', 'VH'),
#  ('的', 'DE'),
#  ('台灣', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('盼', 'VK'),
#  ('促進', 'VK'),
#  ('彼此', 'Nh'),
#  ('更', 'Neqa'),
#  ('多', 'VH'),
#  ('交流', 'VH'),
#  ('機會', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('駐', 'VCL'),
#  ('教廷', 'Nc'),
#  ('大使', 'Na'),
#  ('李世明', 'Nb'),
#  ('致詞', 'VA'),
#  ('介紹', 'VE'),
#  ('台灣', 'Nc'),
#  ('時', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('引用', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('時事哏', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('開場', 'VA'),
#  ('博', 'VJ'),
#  ('得', 'DE'),
#  ('眾人鼓掌大笑', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('他', 'Nh'),
#  ('表示', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('日前', 'Nd'),
#  ('美國', 'Nc'),
#  ('總統', 'Na'),
#  ('川普', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Donald', 'FW'),
#  (' Trump', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('與', 'P'),
#  ('烏克蘭', 'Nc'),
#  ('總統', 'Na'),
#  ('澤倫斯基', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Volodymyr Zelenskyy', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('在', 'P'),
#  ('白宮', 'Nc'),
#  ('會晤', 'VC'),
#  ('後', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('有', 'V_2'),
#  ('句', 'Nf'),
#  ('流行語', 'Na'),
#  ('在', 'P'),
#  ('國際社會', 'Nc'),
#  ('很', 'Dfa'),
#  ('夯', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('就是', 'Cbb'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('你', 'Nh'),
#  ('手', 'Na'),
#  ('上', 'Ncd'),
#  ('有', 'V_2'),
#  ('什麼', 'Nep'),
#  ('牌', 'Na'),
#  ('可', 'D'),
#  ('打', 'VC'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Na'),
#  ('論', 'VC'),
#  ('領土', 'Na'),
#  ('面積', 'Na'),
#  ('雖', 'Cbb'),
#  ('小', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('但', 'Cbb'),
#  ('台灣', 'Nc'),
#  ('對', 'P'),
#  ('國際', 'Nc'),
#  ('很', 'Dfa'),
#  ('重要', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('可', 'D'),
#  ('說', 'VE'),
#  ('手', 'Na'),
#  ('上', 'Ncd'),
#  ('有', 'V_2'),
#  ('很多', 'Neqa'),
#  ('牌', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('其', 'Nep'),
#  ('重要性', 'Na'),
#  ('可', 'D'),
#  ('分', 'VC'),
#  ('3', 'Neu'),
#  ('個', 'Nf'),
#  ('主要', 'A'),
#  ('方面', 'Na'),
#  ('闡釋', 'VC'),
#  ('。', 'PERIODCATEGORY'),
#  ('李世明', 'Nb'),
#  ('說', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('首先', 'D'),
#  ('台灣', 'Nc'),
#  ('具有', 'VJ'),
#  ('地緣', 'Na'),
#  ('戰略', 'Na'),
#  ('重要性', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('海峽', 'Na'),
#  ('是', 'SHI'),
#  ('全球', 'Nc'),
#  ('貨運', 'Na'),
#  ('通過', 'VC'),
#  ('的', 'DE'),
#  ('重要', 'VH'),
#  ('管道', 'Na'),
#  ('；', 'SEMICOLONCATEGORY'),
#  ('第二', 'Neu'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('半導體', 'Na'),
#  ('產業', 'Na'),
#  ('位居', 'VCL'),
#  ('世界', 'Nc'),
#  ('關鍵', 'Na'),
#  ('地位', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('先進', 'VH'),
#  ('晶片', 'Na'),
#  ('製程', 'Na'),
#  ('在', 'P'),
#  ('全球', 'Nc'),
#  ('市占率', 'Na'),
#  ('超過', 'VJ'),
#  ('9成', 'Neqa'),
#  ('。', 'PERIODCATEGORY'),
#  ('李世明', 'Nb'),
#  ('表示', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('第三', 'Neu'),
#  ('點', 'Nf'),
#  ('最', 'Dfa'),
#  ('重要', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('教宗方', 'Na'),
#  ('濟各', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Pope', 'FW'),
#  (' ', 'WHITESPACE'),
#  ('Francis', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('說', 'VE'),
#  ('今年', 'Nd'),
#  ('是', 'SHI'),
#  ('希望', 'VK'),
#  ('禧年', 'Nd'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('作為', 'VG'),
#  ('自由', 'VH'),
#  ('民主', 'VH'),
#  ('國家', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('是', 'SHI'),
#  ('所有', 'Neqa'),
#  ('受到', 'VJ'),
#  ('中國', 'Nc'),
#  ('共產', 'A'),
#  ('威權', 'Na'),
#  ('統治', 'VC'),
#  ('下', 'Ng'),
#  ('人民', 'Na'),
#  ('的', 'DE'),
#  ('希望', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('因為', 'Cbb'),
#  ('在', 'P'),
#  ('中國', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('人民', 'Na'),
#  ('無法', 'D'),
#  ('享受', 'VJ'),
#  ('自由', 'Na'),
#  ('與', 'Caa'),
#  ('公平', 'VH'),
#  ('正義', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('台灣', 'Nc'),
#  ('扮演', 'VC'),
#  ('了', 'Di'),
#  ('帶來', 'VC'),
#  ('希望', 'Na'),
#  ('的', 'DE'),
#  ('角色', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('。', 'PERIODCATEGORY'),
#  ('李世明', 'Nb'),
#  ('鼓勵', 'VF'),
#  ('北義菁英', 'Nb'),
#  ('教友', 'Na'),
#  ('到', 'VCL'),
#  ('台灣', 'Nc'),
#  ('訪問', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('現', 'Nd'),
#  ('在', 'P'),
#  ('羅馬', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('米蘭', 'Nc'),
#  ('都', 'D'),
#  ('有', 'V_2'),
#  ('直飛', 'VCL'),
#  ('台灣', 'Nc'),
#  ('班機', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('非常', 'Dfa'),
#  ('方便', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('在', 'VA'),
#  ('場', 'Nc'),
#  ('的', 'DE'),
#  ('布雷西亞', 'Nc'),
#  ('扶輪社', 'Nc'),
#  ('幹部', 'Na'),
#  ('對', 'P'),
#  ('此', 'Nep'),
#  ('反應', 'Na'),
#  ('熱烈', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('當場', 'D'),
#  ('表示', 'VE'),
#  ('要', 'D'),
#  ('公開', 'VHC'),
#  ('徵求', 'VC'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('台灣', 'Nc'),
#  ('扶輪社', 'Nc'),
#  ('姊妹社', 'Nc'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('下', 'Nes'),
#  ('次', 'Nf'),
#  ('立刻', 'D'),
#  ('安排', 'VE'),
#  ('整團', 'Neqa'),
#  ('訪', 'VC'),
#  ('台', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('不少', 'Neqa'),
#  ('教友', 'Na'),
#  ('也', 'D'),
#  ('直', 'D'),
#  ('喊', 'VE'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('報名', 'VA'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('、', 'PAUSECATEGORY'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('加', 'VC'),
#  ('一', 'Neu'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('，', 'COMMACATEGORY'),
#  ('並', 'Cbb'),
#  ('開始', 'VL'),
#  ('向', 'P'),
#  ('使館', 'Nc'),
#  ('人員', 'Na'),
#  ('打探', 'VC'),
#  ('台灣', 'Nc'),
#  ('有', 'V_2'),
#  ('哪些', 'Neqa'),
#  ('美食', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('登山', 'VA'),
#  ('、', 'PAUSECATEGORY'),
#  ('海灘', 'Na'),
#  ('景點', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('展現', 'VC'),
#  ('義大利人', 'Na'),
#  ('熱情', 'VH'),
#  ('的', 'DE'),
#  ('民族性', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('由', 'P'),
#  ('外交部', 'Nc'),
#  ('中美洲', 'Nc'),
#  ('經貿', 'Na'),
#  ('辦事處', 'Nc'),
#  ('籌組', 'VC'),
#  ('的', 'DE'),
#  ('台灣', 'Nc'),
#  ('咖啡', 'Na'),
#  ('考察團', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('力挺', 'VC'),
#  ('友邦', 'Nc'),
#  ('瓜地馬拉', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('預計', 'VE'),
#  ('採購', 'VC'),
#  ('38', 'Neu'),
#  ('個', 'Nf'),
#  ('貨櫃', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('72萬', 'Neu'),
#  ('公斤', 'Nf'),
#  ('咖啡', 'Na'),
#  ('生豆', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('除', 'P'),
#  ('比', 'P'),
#  ('去年', 'Nd'),
#  ('增加', 'VHC'),
#  ('近', 'Nes'),
#  ('5成', 'Neqa'),
#  ('，', 'COMMACATEGORY'),
#  ('考察團', 'Na'),
#  ('規模', 'Na'),
#  ('和', 'Caa'),
#  ('採購量', 'Na'),
#  ('更', 'Dfa'),
#  ('創下', 'VC'),
#  ('歷年', 'Nd'),
#  ('新高', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('台灣', 'Nc'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('2025年', 'Neu'),
#  ('中美洲', 'Nc'),
#  ('咖啡', 'Na'),
#  ('經', 'Na'),
#  ('貿', 'Na'),
#  ('考察團', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('日前', 'Nd'),
#  ('抵達', 'VCL'),
#  ('瓜地馬拉', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('實地', 'D'),
#  ('考察', 'VC'),
#  ('咖啡', 'Na'),
#  ('生產', 'Na'),
#  ('鏈', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('3日', 'Nd'),
#  ('上午', 'Nd'),
#  ('也', 'D'),
#  ('前往', 'VCL'),
#  ('瓜地馬拉', 'Nc'),
#  ('咖啡', 'Nc'),
#  ('協會', 'Nc'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('ANACAFE', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('拜訪', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('並且', 'Cbb'),
#  ('親身', 'Na'),
#  ('杯測', 'Na'),
#  ('瓜國', 'Nc'),
#  ('各', 'Nes'),
#  ('個', 'Nf'),
#  ('產區', 'Nc'),
#  ('，', 'COMMACATEGORY'),
#  ('不同', 'VH'),
#  ('品種', 'Na'),
#  ('風味', 'Na'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('中美洲', 'Nc'),
#  ('經貿', 'Na'),
#  ('辦事處', 'Nc'),
#  ('主任', 'Na'),
#  ('徐韶慧', 'Nb'),
#  ('表示', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('相較', 'VB'),
#  ('去年', 'Nd'),
#  ('1', 'Neu'),
#  ('1', 'Neu'),
#  ('家', 'Nf'),
#  ('台灣', 'Nc'),
#  ('業者', 'Na'),
#  ('組團', 'VA'),
#  ('考察', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('下單', 'Na'),
#  ('採購', 'VC'),
#  ('總價值', 'Na'),
#  ('260萬', 'Neu'),
#  ('美元', 'Nf'),
#  ('，', 'COMMACATEGORY'),
#  ('26', 'Neu'),
#  ('個', 'Nf'),
#  ('貨櫃', 'Na'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('生豆', 'VC'),
#  ('；', 'SEMICOLONCATEGORY'),
#  ('今年', 'Nd'),
#  ('增加到', 'VHC'),
#  ('1', 'Neu'),
#  ('3', 'Neu'),
#  ('家', 'Nf'),
#  ('台灣', 'Nc'),
#  ('業者', 'Na'),
#  ('參與', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('更', 'Dfa'),
#  ('大幅', 'D'),
#  ('採購', 'VC'),
#  ('總計', 'Da'),
#  ('38', 'Neu'),
#  ('個', 'Nf'),
#  ('貨櫃', 'Na'),
#  ('、', 'PAUSECATEGORY'),
#  ('共', 'Da'),
#  ('72萬', 'Neu'),
#  ('公斤', 'Nf'),
#  ('咖啡', 'Na'),
#  ('生', 'VC'),
#  ('豆', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('顯示', 'VK'),
#  ('台灣', 'Nc'),
#  ('消費者', 'Na'),
#  ('對', 'P'),
#  ('瓜地馬拉', 'Nc'),
#  ('咖啡', 'Na'),
#  ('的', 'DE'),
#  ('喜愛', 'Nv'),
#  ('，', 'COMMACATEGORY'),
#  ('更', 'Dfa'),
#  ('凸顯', 'VJ'),
#  ('台', 'Nc'),
#  ('瓜', 'Nc'),
#  ('蓬勃商機', 'VH'),
#  ('發展', 'VC'),
#  ('。', 'PERIODCATEGORY'),
#  ('徐韶慧', 'Nb'),
#  ('強調', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('根據', 'P'),
#  ('統計', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('2024年', 'Neu'),
#  ('瓜地馬拉', 'Nc'),
#  ('進口', 'VC'),
#  ('的', 'DE'),
#  ('咖啡豆', 'Na'),
#  ('占', 'VJ'),
#  ('台灣', 'Nc'),
#  ('咖啡', 'Na'),
#  ('消費', 'Na'),
#  ('總量', 'Na'),
#  ('的', 'DE'),
#  ('10%', 'Neqa'),
#  ('以上', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('是', 'SHI'),
#  ('台灣', 'Nc'),
#  ('第4', 'Neu'),
#  ('大', 'VH'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('進口國', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('換句', 'Dk'),
#  ('話', 'Na'),
#  ('說', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('每', 'D'),
#  ('賣', 'VC'),
#  ('出', 'VC'),
#  ('1', 'Neu'),
#  ('0', 'Neu'),
#  ('杯', 'Nf'),
#  ('咖啡', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('就', 'D'),
#  ('有', 'V_2'),
#  ('超過', 'VJ'),
#  ('1', 'Neu'),
#  ('杯', 'Nf'),
#  ('是', 'SHI'),
#  ('來自', 'VJ'),
#  ('瓜地馬拉', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('此外', 'Cbb'),
#  ('，', 'COMMACATEGORY'),
#  ('台灣', 'Nc'),
#  ('在', 'P'),
#  ('整', 'Neqa'),
#  ('個', 'Nf'),
#  ('亞洲', 'Nc'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('消費國中', 'Na'),
#  ('也', 'D'),
#  ('位居第3', 'VCL'),
#  ('，', 'COMMACATEGORY'),
#  ('僅', 'Da'),
#  ('次於', 'VJ'),
#  ('日本', 'Nc'),
#  ('和', 'Caa'),
#  ('韓國', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('去年', 'Nd'),
#  ('5月', 'Nd'),
#  ('底', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('中國', 'Nc'),
#  ('突然', 'D'),
#  ('宣布', 'VE'),
#  ('禁止', 'VE'),
#  ('瓜地馬拉', 'Nc'),
#  ('夏威夷豆', 'Nc'),
#  ('和', 'Caa'),
#  ('咖啡豆', 'Na'),
#  ('進口', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('作為', 'VG'),
#  ('外交', 'Na'),
#  ('勒索', 'Nv'),
#  ('手段', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('引起', 'VC'),
#  ('瓜國政府', 'Nc'),
#  ('和', 'Caa'),
#  ('業者', 'Na'),
#  ('不滿', 'VK'),
#  ('。', 'PERIODCATEGORY'),
#  ('台灣', 'Nc'),
#  ('外交部', 'Nc'),
#  ('和', 'Caa'),
#  ('台灣', 'Nc'),
#  ('咖啡', 'Na'),
#  ('進口商', 'Na'),
#  ('第一', 'Neu'),
#  ('時間', 'Na'),
#  ('伸出', 'VC'),
#  ('援手', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('將', 'P'),
#  ('這', 'Nep'),
#  ('一', 'Neu'),
#  ('批', 'Nf'),
#  ('咖啡貨櫃', 'Na'),
#  ('轉運往', 'VCL'),
#  ('台灣', 'Nc'),
#  ('。', 'PERIODCATEGORY'),
#  ('中美洲', 'Nc'),
#  ('經貿', 'Na'),
#  ('辦事處', 'Nc'),
#  ('也', 'D'),
#  ('別出心裁', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('將', 'P'),
#  ('這', 'Nep'),
#  ('批', 'Nf'),
#  ('瓜國', 'Nc'),
#  ('咖啡', 'Na'),
#  ('豆', 'Na'),
#  ('製作成', 'VG'),
#  ('濾掛式', 'A'),
#  ('咖啡包', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('在', 'P'),
#  ('此', 'Nep'),
#  ('次', 'Nf'),
#  ('參訪', 'VC'),
#  ('行程', 'Na'),
#  ('更', 'Dfa'),
#  ('將', 'D'),
#  ('致贈', 'VD'),
#  ('瓜國', 'Nc'),
#  ('友人', 'Na'),
#  ('「', 'PARENTHESISCATEGORY'),
#  ('限定版', 'Na'),
#  ('友誼', 'Na'),
#  ('咖啡', 'Na'),
#  ('」', 'PARENTHESISCATEGORY'),
#  ('禮盒', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('成為', 'VG'),
#  ('台灣', 'Nc'),
#  ('力挺', 'VC'),
#  ('瓜國', 'Nc'),
#  ('另', 'Nes'),
#  ('一', 'Neu'),
#  ('種', 'Nf'),
#  ('象徵', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('根據', 'P'),
#  ('瓜地', 'Nc'),
#  ('馬拉', 'Na'),
#  ('中央', 'Nc'),
#  ('銀行', 'Nc'),
#  ('數據', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('2024年', 'Neu'),
#  ('瓜地', 'Nc'),
#  ('馬拉', 'Na'),
#  ('對', 'P'),
#  ('台灣', 'Nc'),
#  ('的', 'DE'),
#  ('咖啡', 'Na'),
#  ('出口', 'VC'),
#  ('超過', 'VJ'),
#  ('1800萬', 'Neu'),
#  ('美元', 'Nf'),
#  ('，', 'COMMACATEGORY'),
#  ('相比於', 'VB'),
#  ('2023年', 'Neu'),
#  ('，', 'COMMACATEGORY'),
#  ('出口量', 'Na'),
#  ('增長', 'VHC'),
#  ('了', 'Di'),
#  ('13%', 'Neqa'),
#  ('；', 'SEMICOLONCATEGORY'),
#  ('而', 'Cbb'),
#  ('咖啡', 'Na'),
#  ('也', 'D'),
#  ('僅', 'Da'),
#  ('次於', 'VJ'),
#  ('糖', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('成為', 'VG'),
#  ('瓜國', 'Nc'),
#  ('出口', 'VC'),
#  ('台灣', 'Nc'),
#  ('的', 'DE'),
#  ('第二', 'Neu'),
#  ('大', 'VH'),
#  ('商品', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('出席', 'Nv'),
#  ('活動', 'Na'),
#  ('的', 'DE'),
#  ('瓜地', 'Nc'),
#  ('馬拉', 'Na'),
#  ('外交部', 'Nc'),
#  ('次長', 'Na'),
#  ('歐洛斯柯', 'Nb'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('Julio Orozco', 'FW'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('特別', 'VH'),
#  ('感謝', 'VK'),
#  ('台灣', 'Nc'),
#  ('和', 'Caa'),
#  ('瓜地馬拉', 'Nc'),
#  ('共同', 'A'),
#  ('推廣', 'VC'),
#  ('咖啡', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('不只', 'Da'),
#  ('進', 'D'),
#  ('一', 'Neu'),
#  ('步', 'Nf'),
#  ('提升', 'VC'),
#  ('全球', 'Nc'),
#  ('市場', 'Nc'),
#  ('地位', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('更', 'Dfa'),
#  ('讓', 'VL'),
#  ('台瓜人民', 'Nc'),
#  ('及', 'Caa'),
#  ('瓜國', 'Nc'),
#  ('咖啡', 'Na'),
#  ('農', 'Na'),
#  ('都', 'D'),
#  ('能夠', 'D'),
#  ('受惠', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('除了', 'P'),
#  ('政治', 'Na'),
#  ('因素', 'Na'),
#  ('干擾', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('近年來', 'Nd'),
#  ('全球', 'Nc'),
#  ('咖啡', 'Na'),
#  ('受到', 'VJ'),
#  ('氣候', 'Na'),
#  ('變遷', 'VH'),
#  ('影響', 'VC'),
#  ('，', 'COMMACATEGORY'),
#  ('產量', 'Na'),
#  ('供應', 'VD'),
#  ('不', 'D'),
#  ('穩', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('市場', 'Nc'),
#  ('價格', 'Na'),
#  ('也', 'D'),
#  ('大幅', 'D'),
#  ('波動', 'VAC'),
#  ('。', 'PERIODCATEGORY'),
#  ('台灣', 'Nc'),
#  ('咖啡', 'Na'),
#  ('考察團', 'Na'),
#  ('業者', 'Na'),
#  ('張正仁', 'Nb'),
#  ('指出', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('過', 'Nd'),
#  ('去', 'VJ'),
#  ('咖啡', 'Na'),
#  ('價格', 'Na'),
#  ('雖然', 'Cbb'),
#  ('每', 'Nes'),
#  ('十', 'Neu'),
#  ('年', 'Nf'),
#  ('就', 'D'),
#  ('會', 'D'),
#  ('有', 'V_2'),
#  ('一', 'Neu'),
#  ('次', 'Nf'),
#  ('上漲', 'Nv'),
#  ('，', 'COMMACATEGORY'),
#  ('但', 'Cbb'),
#  ('基本', 'Na'),
#  ('上', 'Ng'),
#  ('2', 'Neu'),
#  ('、', 'PAUSECATEGORY'),
#  ('3', 'Neu'),
#  ('個', 'Nf'),
#  ('月', 'Na'),
#  ('後', 'Ng'),
#  ('就', 'D'),
#  ('恢復', 'VHC'),
#  ('平穩', 'VH'),
#  ('。', 'PERIODCATEGORY'),
#  ('不過', 'Cbb'),
#  ('自', 'P'),
#  ('COVID-19', 'FW'),
#  ('（', 'PARENTHESISCATEGORY'),
#  ('2019', 'Neu'),
#  ('冠狀', 'Na'),
#  ('病毒', 'Na'),
#  ('疾病', 'Na'),
#  ('）', 'PARENTHESISCATEGORY'),
#  ('疫情', 'Na'),
#  ('後', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('咖啡', 'Na'),
#  ('價格', 'Na'),
#  ('卻', 'D'),
#  ('持續', 'VL'),
#  ('走揚', 'VH'),
#  ('，', 'COMMACATEGORY'),
#  ('這', 'Nep'),
#  ('種', 'Nf'),
#  ('情況', 'Na'),
#  ('是', 'SHI'),
#  ('過數十', 'VCL'),
#  ('年', 'Nf'),
#  ('罕見', 'VH'),
#  ('的', 'T'),
#  ('，', 'COMMACATEGORY'),
#  ('自然', 'D'),
#  ('也', 'D'),
#  ('造成', 'VK'),
#  ('進口商', 'Na'),
#  ('的', 'DE'),
#  ('成本', 'Na'),
#  ('壓力', 'Na'),
#  ('。', 'PERIODCATEGORY'),
#  ('張正仁', 'Nb'),
#  ('強調', 'VE'),
#  ('，', 'COMMACATEGORY'),
#  ('現在', 'Nd'),
#  ('只能', 'Da'),
#  ('觀察', 'VE'),
#  ('3', 'Nd'),
#  ('、', 'PAUSECATEGORY'),
#  ('4', 'Nd'),
#  ('月', 'Na'),
#  ('後', 'Ng'),
#  ('，', 'COMMACATEGORY'),
#  ('全', 'Neqa'),
#  ('世界', 'Nc'),
#  ('第一', 'Neu'),
#  ('大', 'VH'),
#  ('咖啡', 'Na'),
#  ('生產國', 'Na'),
#  ('巴西', 'Nc'),
#  ...]

# %% [markdown]
# ## Concatenate two Counter objects

# %%
c0 =Counter( row0 )
c1 =Counter( row1 )

# %%
c0.most_common(10)
# Out:
# [(('，', 'COMMACATEGORY'), 38),
#  (('台灣', 'Nc'), 19),
#  (('。', 'PERIODCATEGORY'), 12),
#  (('「', 'PARENTHESISCATEGORY'), 10),
#  (('」', 'PARENTHESISCATEGORY'), 10),
#  (('的', 'DE'), 9),
#  (('教友', 'Na'), 7),
#  (('、', 'PAUSECATEGORY'), 7),
#  (('（', 'PARENTHESISCATEGORY'), 6),
#  (('）', 'PARENTHESISCATEGORY'), 6)]

# %%
c1.most_common(10)
# Out:
# [(('，', 'COMMACATEGORY'), 51),
#  (('咖啡', 'Na'), 27),
#  (('台灣', 'Nc'), 18),
#  (('。', 'PERIODCATEGORY'), 18),
#  (('的', 'DE'), 15),
#  (('瓜地馬拉', 'Nc'), 9),
#  (('、', 'PAUSECATEGORY'), 7),
#  (('也', 'D'), 7),
#  (('個', 'Nf'), 6),
#  (('和', 'Caa'), 6)]

# %%
c01 = c0+c1

# %%
c01.most_common(10)
# Out:
# [(('，', 'COMMACATEGORY'), 89),
#  (('台灣', 'Nc'), 37),
#  (('。', 'PERIODCATEGORY'), 30),
#  (('咖啡', 'Na'), 27),
#  (('的', 'DE'), 24),
#  (('、', 'PAUSECATEGORY'), 14),
#  (('「', 'PARENTHESISCATEGORY'), 12),
#  (('」', 'PARENTHESISCATEGORY'), 12),
#  (('（', 'PARENTHESISCATEGORY'), 12),
#  (('）', 'PARENTHESISCATEGORY'), 12)]

# %% [markdown]
# ## All-in-one function

# %%
from collections import Counter

# %%
news_links =['aipl', 'ait', 'aspt']
news_categories=['政治','科技','運動']
# news_links =['aipl', 'ait', 'aspt', 'asc', 'aie', 'amov','ahel','aopl','asoc','acul','acn']
# news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']

# %%
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# %%
# All-in-one function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words  
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter 
        counter_all += counter
        topwords = counter.most_common(10)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(10)
    
    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# %%
# %%time
result = get_top_words()
# Out:
# CPU times: total: 46.9 ms
# Wall time: 47.2 ms

# %%
result[0:2]
# Out:
# [('政治',
#   [('台灣', 45),
#    ('咖啡', 28),
#    ('政府', 14),
#    ('瓜地馬拉', 9),
#    ('現金', 8),
#    ('教友', 7),
#    ('稅收', 7),
#    ('中國', 6),
#    ('瓜國', 6),
#    ('傅崐萁', 6)]),
#  ('科技',
#   [('火箭', 9),
#    ('星艦', 8),
#    ('市場', 7),
#    ('方案', 7),
#    ('太空', 7),
#    ('印度', 6),
#    ('衛星', 6),
#    ('企業', 5),
#    ('雲達', 5),
#    ('科技', 5)])]

# %% [markdown]
# # Save top 200 word frequency for each category

# %%
import pandas as pd

# %%
top_group_words = get_top_words()

# %%
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])

# %%
df_top_group_words
# Out:
#   category                                           top_keys
# 0       政治  [(台灣, 45), (咖啡, 28), (政府, 14), (瓜地馬拉, 9), (現金,...
# 1       科技  [(火箭, 9), (星艦, 8), (市場, 7), (方案, 7), (太空, 7), ...
# 2       運動  [(月薪, 20), (調幅, 13), (球員, 10), (兄弟, 10), (投手, ...
# 3       全部  [(台灣, 53), (咖啡, 28), (月薪, 20), (政府, 14), (調幅, ...

# %%
df_top_group_words.to_csv('cna_news_topkey_with_category_via_token_pos.csv', index=False)

# %% [markdown]
# # Another way (using list) to get the same result (for reference)
#
# 統計分類的熱門關鍵字

# %% [raw]
# # 過濾條件:兩個字以上 特定的詞性
# allowedPOS=['Na','Nb','Nc']
# from collections import Counter
#
# def word_frequency( token_pos_list ):
#     filtered_words =[]
#     for word, pos in token_pos_list:
#         if (pos in allowedPOS) & (len(word) >= 2):
#             filtered_words.append(word)
#         #print('%s %s' % (word, pos))
#     counter = Counter( filtered_words )
#     return counter.most_common( 200 )

# %% [raw]
# %%time
# top_words_group=[]
# group_token_pos_all=[]
# for category in news_categories:
#     df_group = df[df.category == category]
#     group_token_pos =[]
#
#     for gtp in df_group.token_pos:
#         group_token_pos += eval(gtp)
#
#     group_token_pos_all += group_token_pos
#
#     topwords = word_frequency( group_token_pos )
#     d = pd.DataFrame(topwords, columns = ['key','freq'])
#     top_words_group.append([category, topwords])

# %% [markdown]
# # Put them together

# %%
from collections import Counter
import pandas as pd

# 
df = pd.read_csv('cna_news_preprocessed.csv',sep='|')
news_categories=['政治','科技','運動','證卷','產經','娛樂','生活','國際','社會','文化','兩岸']
# Filter condition: two words and specified POS
# 過濾條件:兩個字以上 特定的詞性
allowedPOS=['Na','Nb','Nc']

# 
# get topk keyword function
def get_top_words():
    top_cate_words={} # final result
    counter_all = Counter() # counter for category '全部'
    for category in news_categories:

        df_group = df[df.category == category]

        # concatenate all filtered words in the same category
        words_group = []
        for row in df_group.token_pos:

            # filter words for each news
            filtered_words =[]
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)

            # concatenate filtered words  
            words_group += filtered_words

        # now we can count word frequency
        counter = Counter( words_group )

        # counter 
        counter_all += counter
        topwords = counter.most_common(100)

        # store topwords
        top_cate_words[category]= topwords

    # Process category '全部'
    top_cate_words['全部'] = counter_all.most_common(100)
    
    # To conveniently save data using pandas, we should convert dict to list.
    return list(top_cate_words.items())

# Save top 200 word frequency for each category
top_group_words = get_top_words()
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])
df_top_group_words.to_csv('cna_news_topkey_with_category_via_token_pos.csv', index=False)
